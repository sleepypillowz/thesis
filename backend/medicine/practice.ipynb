# %% [markdown]
# pandas

# %%
import pandas as pd

df = pd.read_csv('AirPassengers.csv', parse_dates=['Month'])
df = df.sort_values("Month")
df
# Out:
#          Month  #Passengers
# 0   1949-01-01          112
# 1   1949-02-01          118
# 2   1949-03-01          132
# 3   1949-04-01          129
# 4   1949-05-01          121
# ..         ...          ...
# 139 1960-08-01          606
# 140 1960-09-01          508
# 141 1960-10-01          461
# 142 1960-11-01          390
# 143 1960-12-01          432
#
# [144 rows x 2 columns]

# %%
df['lag_1'] = df['#Passengers'].shift(1).fillna(0)
df['lag_2'] = df['#Passengers'].shift(2).fillna(0)
df['lag_3'] = df['#Passengers'].shift(3).fillna(0)
df
# Out:
#          Month  #Passengers  lag_1  lag_2  lag_3
# 0   1949-01-01          112    0.0    0.0    0.0
# 1   1949-02-01          118  112.0    0.0    0.0
# 2   1949-03-01          132  118.0  112.0    0.0
# 3   1949-04-01          129  132.0  118.0  112.0
# 4   1949-05-01          121  129.0  132.0  118.0
# ..         ...          ...    ...    ...    ...
# 139 1960-08-01          606  622.0  535.0  472.0
# 140 1960-09-01          508  606.0  622.0  535.0
# 141 1960-10-01          461  508.0  606.0  622.0
# 142 1960-11-01          390  461.0  508.0  606.0
# 143 1960-12-01          432  390.0  461.0  508.0
#
# [144 rows x 5 columns]

# %%
from lightgbm import LGBMRegressor
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
import numpy as np

features = ['lag_1', 'lag_2', 'lag_3',]

X = df[features].values
y = df['#Passengers']

mse_list = []
tscv = TimeSeriesSplit(n_splits=5)

for fold, (train_index, test_index) in enumerate(tscv.split(X)):
    X_train, y_train = X[train_index], y[train_index]
    X_test, y_test = X[test_index], y[test_index]
    
    model = LGBMRegressor(
        random_state=42,
        n_estimators=50,
        learning_rate=0.01,
        max_depth=2,
        num_leaves=31,
        min_child_samples=1
    )
    
    model.fit(X_train, y_train)
    
    predict = model.predict(X_test)
    
    mse = mean_squared_error(y_test, predict)
    
    mse_list.append(mse)
    
    print(f"Fold {fold+1} MSE: {mse:.2f}")

print(f"\nAverage MSE: {mse_list}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from lightgbm import LGBMRegressor
#       2 from sklearn.model_selection import TimeSeriesSplit
#       3 from sklearn.metrics import mean_squared_error
#
# File c:\Users\Admin\OneDrive\Documents\GitHub\thesis\.venv\Lib\site-packages\lightgbm\__init__.py:11
#       7 from pathlib import Path
#       9 # .basic is intentionally loaded as early as possible, to dlopen() lib_lightgbm.{dll,dylib,so}
#      10 # and its dependencies as early as possible
# ---> 11 from .basic import Booster, Dataset, Sequence, register_logger
#      12 from .callback import EarlyStopException, early_stopping, log_evaluation, record_evaluation, reset_parameter
#      13 from .engine import CVBooster, cv, train
#
# File c:\Users\Admin\OneDrive\Documents\GitHub\thesis\.venv\Lib\site-packages\lightgbm\basic.py:9
# ...

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Admin\OneDrive\Documents\GitHub\thesis\.venv\Scripts\python.exe
